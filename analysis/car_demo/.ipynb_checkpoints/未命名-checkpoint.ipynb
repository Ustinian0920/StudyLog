# %%
import numpy as np
import pandas as pd

# %%
source_df = pd.read_csv("./car.csv")
source_df
# Out:
#                              carname carprice carbrand cartype powerway  \
# 0             汉EV 2022款 创世版 715KM尊荣型   27.18万      比亚迪    中大型车      纯电动
# 1       威霆 2013款 2.5L 自动 前驱 7座 原厂定制版     暂无报价      NaN      汽油      NaN
# 2     奔驰GL级 2016款 3.0T 自动 四驱 5座 平行进口     暂无报价      NaN      汽油      NaN
# 3                                0款      暂无报价      NaN      汽油      NaN
# 4      宝马X6 2016款 3.0T 自动 四驱 5座 平行进口     暂无报价      NaN      汽油      NaN
# ...                              ...      ...      ...     ...      ...
# 6595       览拓者 2023款 2.0T手动四驱柴油精英型标箱   12.49万     长安汽车    中型皮卡       柴油
# 6596       览拓者 2023款 2.0T手动四驱柴油领航型长箱   13.79万     长安汽车    中型皮卡       柴油
# 6597       览拓者 2023款 2.0T手动两驱汽油时尚型长箱    9.99万     长安汽车    中型皮卡       汽油
# 6598       览拓者 2023款 2.0T手动两驱汽油精英型长箱   10.49万     长安汽车    中型皮卡       汽油
# 6599       览拓者 2023款 2.0T手动四驱汽油精英型长箱   11.79万     长安汽车    中型皮卡       汽油
#
#      timemark      car_motor motor_type car_gl car_nj battery_type  \
# ...

# %%
for column in source_df:
    print(source_df[column].isna().sum())
# Out:
# 0
# 0
# 2964
# 1666
# 3138
# 2922
# 2800
# 2856
# 2807
# 2828
# 2825
# 2881
# 2909
# 5723
# 2820
# 2826
# 2947

# %%
df = source_df.dropna()
df
# Out:
#                            carname carprice carbrand cartype powerway  \
# 0           汉EV 2022款 创世版 715KM尊荣型   27.18万      比亚迪    中大型车      纯电动
# 27         长安Lumin 2022款 155km 清甜款    4.99万     长安汽车     微型车      纯电动
# 35       海豹 2022款 550KM 标准续航后驱版精英型   21.28万      比亚迪     中型车      纯电动
# 36       海豹 2022款 550KM 标准续航后驱版尊贵型   22.58万      比亚迪     中型车      纯电动
# 39           海豹 2022款 700KM 长续航后驱版   26.28万      比亚迪     中型车      纯电动
# ...                            ...      ...      ...     ...      ...
# 6530  五菱宏光MINIEV 2022款 马卡龙缤纷款 磷酸铁锂    4.68万   上汽通用五菱     微型车      纯电动
# 6531   五菱宏光MINIEV 2022款 马卡龙绘色款 三元锂    5.28万   上汽通用五菱     微型车      纯电动
# 6532  五菱宏光MINIEV 2022款 马卡龙绘色款 磷酸铁锂    5.28万   上汽通用五菱     微型车      纯电动
# 6562       MG MULAN 2022款 425km旗舰版   14.78万     上汽集团    紧凑型车      纯电动
# 6563       MG MULAN 2022款 520km豪华版   15.38万     上汽集团    紧凑型车      纯电动
#
#      timemark  car_motor motor_type car_gl car_nj battery_type battery_tec  \
# ...

# %%
dic = {
    "carname" = []
    "carprice" = [],
    "carbrand" = [],
}

dic["carname"].append("name")
dic["carname"].append("")

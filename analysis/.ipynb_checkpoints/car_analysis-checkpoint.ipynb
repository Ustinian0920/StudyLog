# %%
import pandas as pd
import numpy as np

# %%
source_df = pd.read_excel("./cars.xls")
source_df
# Out:
#       id                                               link    car_name  \
# 0      1  //p3.dcarimg.com/img/motor-img/a7188d742fdf951...  宋PLUS DM-i
# 1      2  //p3.dcarimg.com/img/motor-img/6efbde874de291b...  五菱宏光MINIEV
# 2      3  //p3.dcarimg.com/img/motor-img/d83515c32b2e655...          轩逸
# 3      4  //p3.dcarimg.com/img/motor-img/28d677a5f94a5a2...          朗逸
# 4      5  //p3.dcarimg.com/img/motor-img/369ece92bbd1c98...     Model Y
# ..   ...                                                ...         ...
# 626  627  //p3.dcarimg.com/img/mosaic-legacy/bef30000983...     富康ES500
# 627  628  //p3.dcarimg.com/img/motor-img/6def6668eda5c8d...     菲斯塔 纯电动
# 628  629  //p3.dcarimg.com/img/motor-img/6fac1ec13425465...        北京X5
# 629  630  //p3.dcarimg.com/img/motor-img/3775b0fd779b392...       奔腾E01
# 630  631  //p3.dcarimg.com/img/motor-img/d4da85bed05700a...        北京U7
#
#        car_brand         price    sales
# 0     比亚迪/紧凑型suv  15.48-21.88万  400,041
# 1     上汽通用五菱/微型车    2.98-9.99万  394,557
# 2      东风日产/紧凑型车   7.38-15.59万  394,190
# 3      上汽大众/紧凑型车   6.69-12.99万  332,759
# 4    特斯拉中国/中型suv  26.19-35.99万  313,140
# ..           ...           ...      ...
# 626    神龙汽车/紧凑型车        14.18万       11
# 627    北京现代/紧凑型车  11.08-13.58万       11
# 628  北京汽车/紧凑型suv   7.19-10.19万        8
# 629   一汽奔腾/中型suv  19.68-22.88万        7
# 630     北京汽车/中型车   8.11-11.61万        3
#
# [631 rows x 6 columns]

# %%
source_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         631 non-null    int64
#  1   link       631 non-null    object
#  2   car_name   631 non-null    object
#  3   car_brand  631 non-null    object
#  4   price      631 non-null    object
#  5   sales      631 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 29.7+ KB

# %% [markdown]
# ### 数据清洗

# %%
df = source_df[["car_name","car_brand","price","sales"]].copy()
df = df.query('price!="暂无报价"')
df[["brand_name","model"]] = df["car_brand"].str.split("/",expand=True)
df["price"] = df["price"].str.strip("万")
df[["min_price","max_price"]] = df["price"].str.split("-",expand=True)
df = df[["car_name","brand_name","model","min_price","max_price","sales"]]
df["sales"] = df["sales"].str.replace(",","")
df[["min_price","max_price","sales"]] = df[["min_price","max_price","sales"]].apply(pd.to_numeric,axis=1)
df.loc[df['max_price'].isnull(),'max_price'] = df[df['max_price'].isnull()]['min_price'] 
df["sales_volume"] = (df["min_price"]+df["max_price"])/2*df["sales"]
df
# Out:
#        car_name brand_name   model  min_price  max_price     sales  \
# 0    宋PLUS DM-i        比亚迪  紧凑型suv      15.48      21.88  400041.0
# 1    五菱宏光MINIEV     上汽通用五菱     微型车       2.98       9.99  394557.0
# 2            轩逸       东风日产    紧凑型车       7.38      15.59  394190.0
# 3            朗逸       上汽大众    紧凑型车       6.69      12.99  332759.0
# 4       Model Y      特斯拉中国   中型suv      26.19      35.99  313140.0
# ..          ...        ...     ...        ...        ...       ...
# 626     富康ES500       神龙汽车    紧凑型车      14.18      14.18      11.0
# 627     菲斯塔 纯电动       北京现代    紧凑型车      11.08      13.58      11.0
# 628        北京X5       北京汽车  紧凑型suv       7.19      10.19       8.0
# 629       奔腾E01       一汽奔腾   中型suv      19.68      22.88       7.0
# 630        北京U7       北京汽车     中型车       8.11      11.61       3.0
#
#      sales_volume
# 0     7472765.880
# 1     2558702.145
# 2     4527272.150
# 3     3274348.560
# 4     9735522.600
# ..            ...
# 626       155.980
# 627       135.630
# 628        69.520
# 629       148.960
# 630        29.580
#
# [626 rows x 7 columns]

# %%
df.set_index("sales")
# Out:
#             car_name brand_name   model  min_price  max_price  sales_volume
# sales
# 400041.0  宋PLUS DM-i        比亚迪  紧凑型suv      15.48      21.88   7472765.880
# 394557.0  五菱宏光MINIEV     上汽通用五菱     微型车       2.98       9.99   2558702.145
# 394190.0          轩逸       东风日产    紧凑型车       7.38      15.59   4527272.150
# 332759.0          朗逸       上汽大众    紧凑型车       6.69      12.99   3274348.560
# 313140.0     Model Y      特斯拉中国   中型suv      26.19      35.99   9735522.600
# ...              ...        ...     ...        ...        ...           ...
# 11.0         富康ES500       神龙汽车    紧凑型车      14.18        NaN           NaN
# 11.0         菲斯塔 纯电动       北京现代    紧凑型车      11.08      13.58       135.630
# 8.0             北京X5       北京汽车  紧凑型suv       7.19      10.19        69.520
# 7.0            奔腾E01       一汽奔腾   中型suv      19.68      22.88       148.960
# 3.0             北京U7       北京汽车     中型车       8.11      11.61        29.580
#
# [626 rows x 6 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

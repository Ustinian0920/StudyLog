# %% [markdown]
# ## 生成数据表

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "id": [1001, 1002, 1003, 1004, 1005, 1006],
        "date":
        pd.date_range('20130102', periods=6),
        "city":
        ['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
        "age": [23, 44, 54, 32, 34, 32],
        "category": ['100-A', '100-B', '110-A', '110-C', '210-A', '130-F'],
        "price": [1200, np.nan, 2133, 5433, np.nan, 4432]
    },
    columns=['id', 'date', 'city', 'category', 'age', 'price'])

# %% [markdown]
# ## 信息表查看

# %% [markdown]
# ###  维度查看

# %%
df.shape
# Out:
# (6, 6)

# %% [markdown]
# ### 数据表基本信息（维度、列名称、数据格式、所占空间等）

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        6 non-null      int64
#  1   date      6 non-null      datetime64[ns]
#  2   city      6 non-null      object
#  3   category  6 non-null      object
#  4   age       6 non-null      int64
#  5   price     4 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 416.0+ bytes

# %% [markdown]
# ### 数据表统计信息（平均值，最大值，最小值等）

# %%
df[['age','price']].describe()
# Out:
#             age        price
# count   6.00000     4.000000
# mean   36.50000  3299.500000
# std    10.87658  1966.638503
# min    23.00000  1200.000000
# 25%    32.00000  1899.750000
# 50%    33.00000  3282.500000
# 75%    41.50000  4682.250000
# max    54.00000  5433.000000

# %% [markdown]
# ### 每一列数据的格式

# %%
df.dtypes
# Out:
# id                   int64
# date        datetime64[ns]
# city                object
# category            object
# age                  int64
# price              float64
# dtype: object

# %% [markdown]
# ### 某一列格式

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### 空值

# %%
df.isnull()
# Out:
#       id   date   city  category    age  price
# 0  False  False  False     False  False  False
# 1  False  False  False     False  False   True
# 2  False  False  False     False  False  False
# 3  False  False  False     False  False  False
# 4  False  False  False     False  False   True
# 5  False  False  False     False  False  False

# %% [markdown]
# ### 查看某一列的空值

# %%
df['age'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: age, dtype: bool

# %% [markdown]
# ### 查看某一列的唯一值

# %%
df['age'].unique()
# Out:
# array([23, 44, 54, 32, 34])

# %% [markdown]
# ### 查看数据表的值

# %%
df.values
# Out:
# array([[1001, Timestamp('2013-01-02 00:00:00'), 'Beijing ', '100-A', 23,
#         1200.0],
#        [1002, Timestamp('2013-01-03 00:00:00'), 'SH', '100-B', 44, nan],
#        [1003, Timestamp('2013-01-04 00:00:00'), ' guangzhou ', '110-A',
#         54, 2133.0],
#        [1004, Timestamp('2013-01-05 00:00:00'), 'Shenzhen', '110-C', 32,
#         5433.0],
#        [1005, Timestamp('2013-01-06 00:00:00'), 'shanghai', '210-A', 34,
#         nan],
#        [1006, Timestamp('2013-01-07 00:00:00'), 'BEIJING ', '130-F', 32,
#         4432.0]], dtype=object)

# %% [markdown]
# ### 查看列的名称

# %%
df.columns
# Out:
# Index(['id', 'date', 'city', 'category', 'age', 'price'], dtype='object')

# %% [markdown]
# ### 查看前五行

# %%
df.head()
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN

# %% [markdown]
# ### 后五行数据

# %%
df.tail()
# Out:
#      id       date         city category  age   price
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %% [markdown]
# ## 数据表清洗

# %% [markdown]
# ### 用0填充空值

# %%
df.fillna(value=0)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %% [markdown]
# ### 用price的均值对price的NA进行填充

# %%
df['price'].fillna(value=(df['price'].mean()))
# Out:
# 0    1200.0
# 1    3299.5
# 2    2133.0
# 3    5433.0
# 4    3299.5
# 5    4432.0
# Name: price, dtype: float64

# %% [markdown]
# ### 清除city字段的字符空格

# %%
df['city']=df['city'].map(str.strip)

# %% [markdown]
# ### 大小写转换

# %%
df['city'] = df['city'].str.lower()

# %% [markdown]
# ### 更改数据格式

# %%
df['price'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/s7/wc441d4x0kx0dl7k_7qj2r8r0000gn/T/ipykernel_5837/1064040782.py in <module>
# ----> 1 df['price'].astype('int64')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1146
#    1147     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1148         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1149
#    1150     elif is_object_dtype(arr.dtype):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1191     """
#    1192     if not np.isfinite(values).all():
# -> 1193         raise IntCastingNaNError(
#    1194             "Cannot convert non-finite values (NA or inf) to integer"
#    1195         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# ### 更改列名称

# %%
df.rename(columns={'category':'category-size'})

# %% [markdown]
# ### 删除后出现的重复你值

# %%
df['city'].drop_duplicates()

# %% [markdown]
# ### 删除先出现的重复值

# %%
df['city'].drop_duplicates(keep='last')
# Out:
# 1           sh
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# 5      beijing
# Name: city, dtype: object

# %% [markdown]
# ### 数据替换

# %%
df['city'].replace('sh','shanghai')
# Out:
# 0      beijing
# 1     shanghai
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# 5      beijing
# Name: city, dtype: object

# %% [markdown]
# ## 数据预处理

# %%
df1=pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006,1007,1008], 
"gender":['male','female','male','female','male','female','male','female'],
"pay":['Y','N','Y','Y','N','Y','N','Y',],
"m-point":[10,12,20,40,40,40,30,20]})

# %% [markdown]
# ### 数据表合并

# %% [markdown]
# #### merge

# %%
df_inner = pd.merge(df,df1,how='inner')
df_inner
# Out:
#      id       date       city category  age   price  gender pay  m-point
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40

# %%
df_left = pd.merge(df,df1,how='left')
df_left
# Out:
#      id       date       city category  age   price  gender pay  m-point
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40

# %%
# 笛卡尔积
df_cross = pd.merge(df,df1,how='cross')
df_cross
# Out:
#     id_x       date       city category  age   price  id_y  gender pay  \
# 0   1001 2013-01-02    beijing    100-A   23  1200.0  1001    male   Y
# 1   1001 2013-01-02    beijing    100-A   23  1200.0  1002  female   N
# 2   1001 2013-01-02    beijing    100-A   23  1200.0  1003    male   Y
# 3   1001 2013-01-02    beijing    100-A   23  1200.0  1004  female   Y
# 4   1001 2013-01-02    beijing    100-A   23  1200.0  1005    male   N
# 5   1001 2013-01-02    beijing    100-A   23  1200.0  1006  female   Y
# 6   1001 2013-01-02    beijing    100-A   23  1200.0  1007    male   N
# 7   1001 2013-01-02    beijing    100-A   23  1200.0  1008  female   Y
# 8   1002 2013-01-03         sh    100-B   44     NaN  1001    male   Y
# 9   1002 2013-01-03         sh    100-B   44     NaN  1002  female   N
# 10  1002 2013-01-03         sh    100-B   44     NaN  1003    male   Y
# 11  1002 2013-01-03         sh    100-B   44     NaN  1004  female   Y
# 12  1002 2013-01-03         sh    100-B   44     NaN  1005    male   N
# 13  1002 2013-01-03         sh    100-B   44     NaN  1006  female   Y
# 14  1002 2013-01-03         sh    100-B   44     NaN  1007    male   N
# 15  1002 2013-01-03         sh    100-B   44     NaN  1008  female   Y
# 16  1003 2013-01-04  guangzhou    110-A   54  2133.0  1001    male   Y
# 17  1003 2013-01-04  guangzhou    110-A   54  2133.0  1002  female   N
# 18  1003 2013-01-04  guangzhou    110-A   54  2133.0  1003    male   Y
# 19  1003 2013-01-04  guangzhou    110-A   54  2133.0  1004  female   Y
# 20  1003 2013-01-04  guangzhou    110-A   54  2133.0  1005    male   N
# 21  1003 2013-01-04  guangzhou    110-A   54  2133.0  1006  female   Y
# 22  1003 2013-01-04  guangzhou    110-A   54  2133.0  1007    male   N
# 23  1003 2013-01-04  guangzhou    110-A   54  2133.0  1008  female   Y
# 24  1004 2013-01-05   shenzhen    110-C   32  5433.0  1001    male   Y
# 25  1004 2013-01-05   shenzhen    110-C   32  5433.0  1002  female   N
# 26  1004 2013-01-05   shenzhen    110-C   32  5433.0  1003    male   Y
# 27  1004 2013-01-05   shenzhen    110-C   32  5433.0  1004  female   Y
# 28  1004 2013-01-05   shenzhen    110-C   32  5433.0  1005    male   N
# 29  1004 2013-01-05   shenzhen    110-C   32  5433.0  1006  female   Y
# 30  1004 2013-01-05   shenzhen    110-C   32  5433.0  1007    male   N
# 31  1004 2013-01-05   shenzhen    110-C   32  5433.0  1008  female   Y
# 32  1005 2013-01-06   shanghai    210-A   34     NaN  1001    male   Y
# 33  1005 2013-01-06   shanghai    210-A   34     NaN  1002  female   N
# 34  1005 2013-01-06   shanghai    210-A   34     NaN  1003    male   Y
# 35  1005 2013-01-06   shanghai    210-A   34     NaN  1004  female   Y
# 36  1005 2013-01-06   shanghai    210-A   34     NaN  1005    male   N
# 37  1005 2013-01-06   shanghai    210-A   34     NaN  1006  female   Y
# 38  1005 2013-01-06   shanghai    210-A   34     NaN  1007    male   N
# 39  1005 2013-01-06   shanghai    210-A   34     NaN  1008  female   Y
# 40  1006 2013-01-07    beijing    130-F   32  4432.0  1001    male   Y
# 41  1006 2013-01-07    beijing    130-F   32  4432.0  1002  female   N
# 42  1006 2013-01-07    beijing    130-F   32  4432.0  1003    male   Y
# 43  1006 2013-01-07    beijing    130-F   32  4432.0  1004  female   Y
# 44  1006 2013-01-07    beijing    130-F   32  4432.0  1005    male   N
# 45  1006 2013-01-07    beijing    130-F   32  4432.0  1006  female   Y
# 46  1006 2013-01-07    beijing    130-F   32  4432.0  1007    male   N
# 47  1006 2013-01-07    beijing    130-F   32  4432.0  1008  female   Y
#
#     m-point
# 0        10
# 1        12
# 2        20
# 3        40
# 4        40
# 5        40
# 6        30
# 7        20
# 8        10
# 9        12
# 10       20
# 11       40
# 12       40
# 13       40
# 14       30
# 15       20
# 16       10
# 17       12
# 18       20
# 19       40
# 20       40
# 21       40
# 22       30
# 23       20
# 24       10
# 25       12
# 26       20
# 27       40
# 28       40
# 29       40
# 30       30
# 31       20
# 32       10
# 33       12
# 34       20
# 35       40
# 36       40
# 37       40
# 38       30
# 39       20
# 40       10
# 41       12
# 42       20
# 43       40
# 44       40
# 45       40
# 46       30
# 47       20

# %% [markdown]
# #### append

# %%
result = df.append(df1)
result
# Out:
# /var/folders/s7/wc441d4x0kx0dl7k_7qj2r8r0000gn/T/ipykernel_5837/192711353.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = df.append(df1)
#      id       date       city category   age   price  gender  pay  m-point
# 0  1001 2013-01-02    beijing    100-A  23.0  1200.0     NaN  NaN      NaN
# 1  1002 2013-01-03         sh    100-B  44.0     NaN     NaN  NaN      NaN
# 2  1003 2013-01-04  guangzhou    110-A  54.0  2133.0     NaN  NaN      NaN
# 3  1004 2013-01-05   shenzhen    110-C  32.0  5433.0     NaN  NaN      NaN
# 4  1005 2013-01-06   shanghai    210-A  34.0     NaN     NaN  NaN      NaN
# 5  1006 2013-01-07    beijing    130-F  32.0  4432.0     NaN  NaN      NaN
# 0  1001        NaT        NaN      NaN   NaN     NaN    male    Y     10.0
# 1  1002        NaT        NaN      NaN   NaN     NaN  female    N     12.0
# 2  1003        NaT        NaN      NaN   NaN     NaN    male    Y     20.0
# 3  1004        NaT        NaN      NaN   NaN     NaN  female    Y     40.0
# 4  1005        NaT        NaN      NaN   NaN     NaN    male    N     40.0
# 5  1006        NaT        NaN      NaN   NaN     NaN  female    Y     40.0
# 6  1007        NaT        NaN      NaN   NaN     NaN    male    N     30.0
# 7  1008        NaT        NaN      NaN   NaN     NaN  female    Y     20.0

# %% [markdown]
# #### join

# %%
df2 = df1[['gender','pay']]
result = df.join(df2)
result
# Out:
#      id       date       city category  age   price  gender pay
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y

# %% [markdown]
# #### concat

# %%
df,df1,df2
# Out:
# (     id       date       city category  age   price
#  0  1001 2013-01-02    beijing    100-A   23  1200.0
#  1  1002 2013-01-03         sh    100-B   44     NaN
#  2  1003 2013-01-04  guangzhou    110-A   54  2133.0
#  3  1004 2013-01-05   shenzhen    110-C   32  5433.0
#  4  1005 2013-01-06   shanghai    210-A   34     NaN
#  5  1006 2013-01-07    beijing    130-F   32  4432.0,
#       id  gender pay  m-point
#  0  1001    male   Y       10
#  1  1002  female   N       12
#  2  1003    male   Y       20
#  3  1004  female   Y       40
#  4  1005    male   N       40
#  5  1006  female   Y       40
#  6  1007    male   N       30
#  7  1008  female   Y       20,
#     gender pay
#  0    male   Y
#  1  female   N
#  2    male   Y
#  3  female   Y
#  4    male   N
#  5  female   Y
#  6    male   N
#  7  female   Y)

# %%
frames = [df1,df2]
pd.concat(frames,join='inner',axis=1)
# Out:
#      id  gender pay  m-point  gender pay
# 0  1001    male   Y       10    male   Y
# 1  1002  female   N       12  female   N
# 2  1003    male   Y       20    male   Y
# 3  1004  female   Y       40  female   Y
# 4  1005    male   N       40    male   N
# 5  1006  female   Y       40  female   Y
# 6  1007    male   N       30    male   N
# 7  1008  female   Y       20  female   Y

# %% [markdown]
# ### 设置索引列

# %%
df_inner.set_index('id')
# Out:
#            date       city category  age   price  gender pay  m-point
# id
# 1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20
# 1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40

# %% [markdown]
# ### 按照索引列排序

# %%
df_inner.sort_index()
# Out:
#      id       date       city category  age   price  gender pay  m-point
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40

# %% [markdown]
# ### 按照特定列的值排序

# %%
df_inner.sort_values(by=['age'])
# Out:
#      id       date       city category  age   price  gender pay  m-point
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20

# %% [markdown]
# ### 如果price列的值>3000，group显示high，否则显示low

# %%
df_inner['group'] = np.where(df_inner['price']>3000,'high','low')
df_inner
# Out:
#      id       date       city category  age   price  gender pay  m-point group
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10   low
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12   low
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20   low
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40  high
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40   low
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40  high

# %% [markdown]
# ### 对符合多个条件的数据进行分组标记

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: price, dtype: bool

# %%
df_inner.loc[(df_inner['city']=='beijing') & (df_inner['price']>=4000),'sign'] = 1
df_inner
# Out:
#      id       date       city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02    beijing    100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh    100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou    110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai    210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing    130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1   low   NaN
# 2   low   NaN
# 3  high   NaN
# 4   low   NaN
# 5  high   1.0

# %% [markdown]
# ### 对category字段的值依次进行分列，并创建数据表，索引值为df_inner的索引列，列名称为category和size

# %%
df_inner['category']
# Out:
# 0    100-A
# 1    100-B
# 2    110-A
# 3    110-C
# 4    210-A
# 5    130-F
# Name: category, dtype: object

# %%
split = pd.DataFrame((x.split('-') for x in df_inner['category']),index=df_inner.index,columns=['category','size'])
split
# Out:
#   category size
# 0      100    A
# 1      100    B
# 2      110    A
# 3      110    C
# 4      210    A
# 5      130    F

# %% [markdown]
# ### 将完成分裂后的数据表和原df_inner数据表进行匹配

# %%
df_inner = pd.merge(df_inner,split,right_index=True,left_index=True)
df_inner
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh      100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing      130-F   32  4432.0  female   Y       40
#
#   group  sign category_y size
# 0   low   NaN        100    A
# 1   low   NaN        100    B
# 2   low   NaN        110    A
# 3  high   NaN        110    C
# 4   low   NaN        210    A
# 5  high   1.0        130    F

# %% [markdown]
# ## 数据提取

# %% [markdown]
# ### & “与”

# %%
df_inner
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh      100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing      130-F   32  4432.0  female   Y       40
#
#   group  sign category_y size
# 0   low   NaN        100    A
# 1   low   NaN        100    B
# 2   low   NaN        110    A
# 3  high   NaN        110    C
# 4   low   NaN        210    A
# 5  high   1.0        130    F

# %%
df_inner.loc[((df_inner['age']>25) & (df_inner['city']=='beijing')),['id','city','age','gender']]
# Out:
#      id     city  age  gender
# 5  1006  beijing   32  female

# %% [markdown]
# ### ｜ “或”

# %%
df_inner.loc[((df_inner['age']>25) | (df_inner['city']=='beijing')),['id','city','age','gender']]
# Out:
#      id       city  age  gender
# 0  1001    beijing   23    male
# 1  1002         sh   44  female
# 2  1003  guangzhou   54    male
# 3  1004   shenzhen   32  female
# 4  1005   shanghai   34    male
# 5  1006    beijing   32  female

# %% [markdown]
# ### ！ “非”

# %%
df_inner.loc[(df_inner['city']!='beijing'),['id','city','age','gender']]
# Out:
#      id       city  age  gender
# 1  1002         sh   44  female
# 2  1003  guangzhou   54    male
# 3  1004   shenzhen   32  female
# 4  1005   shanghai   34    male

# %% [markdown]
# ### 对筛选后的数据按city进行计数

# %%
df_inner.loc[(df_inner['city']!='beijing'),['id','city','age','gender']].sort_values(['id']).city.count()
# Out:
# 4

# %% [markdown]
# ### 使用query函数进行筛选

# %%
df_inner.query('city == ["beijing","shanghai"]')
# Out:
#      id       date      city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02   beijing      100-A   23  1200.0    male   Y       10
# 4  1005 2013-01-06  shanghai      210-A   34     NaN    male   N       40
# 5  1006 2013-01-07   beijing      130-F   32  4432.0  female   Y       40
#
#   group  sign category_y size
# 0   low   NaN        100    A
# 4   low   NaN        210    A
# 5  high   1.0        130    F

# %% [markdown]
# ### 对筛选后的结果按price进行求和

# %%
df_inner.query('city == ["beijing","shanghai"]').price.sum()
# Out:
# 5632.0

# %% [markdown]
# ## 数据汇总

# %% [markdown]
# ### 对所有的列进行计数汇总

# %%
df_inner
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh      100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing      130-F   32  4432.0  female   Y       40
#
#   group  sign category_y size
# 0   low   NaN        100    A
# 1   low   NaN        100    B
# 2   low   NaN        110    A
# 3  high   NaN        110    C
# 4   low   NaN        210    A
# 5  high   1.0        130    F

# %%
df_inner.groupby('city').count()
# Out:
#            id  date  category_x  age  price  gender  pay  m-point  group  \
# city
# beijing     2     2           2    2      2       2    2        2      2
# guangzhou   1     1           1    1      1       1    1        1      1
# sh          1     1           1    1      0       1    1        1      1
# shanghai    1     1           1    1      0       1    1        1      1
# shenzhen    1     1           1    1      1       1    1        1      1
#
#            sign  category_y  size
# city
# beijing       1           2     2
# guangzhou     0           1     1
# sh            0           1     1
# shanghai      0           1     1
# shenzhen      0           1     1

# %% [markdown]
# ### 按city对id字段进行计数

# %%
df_inner.groupby('city')['id'].count()
# Out:
# city
# beijing      2
# guangzhou    1
# sh           1
# shanghai     1
# shenzhen     1
# Name: id, dtype: int64

# %% [markdown]
# ### 对两个字段进行汇总计数

# %%
df_inner.groupby(['city','size'])['id'].count()
# Out:
# city       size
# beijing    A       1
#            F       1
# guangzhou  A       1
# sh         B       1
# shanghai   A       1
# shenzhen   C       1
# Name: id, dtype: int64

# %% [markdown]
# ### 对city字段进行汇总，并分别计算price对合计和均值

# %%
df_inner.groupby('city')['price'].agg([len,np.sum,np.mean])
# Out:
#            len     sum    mean
# city
# beijing      2  5632.0  2816.0
# guangzhou    1  2133.0  2133.0
# sh           1     0.0     NaN
# shanghai     1     0.0     NaN
# shenzhen     1  5433.0  5433.0

# %% [markdown]
# ## 数据统计

# %% [markdown]
# ### 简单的数据采样

# %%
df_inner.sample(n=3)
# Out:
#      id       date      city category_x  age   price  gender pay  m-point  \
# 1  1002 2013-01-03        sh      100-B   44     NaN  female   N       12
# 3  1004 2013-01-05  shenzhen      110-C   32  5433.0  female   Y       40
# 0  1001 2013-01-02   beijing      100-A   23  1200.0    male   Y       10
#
#   group  sign category_y size
# 1   low   NaN        100    B
# 3  high   NaN        110    C
# 0   low   NaN        100    A

# %%
df_inner
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03         sh      100-B   44     NaN  female   N       12
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
# 5  1006 2013-01-07    beijing      130-F   32  4432.0  female   Y       40
#
#   group  sign category_y size
# 0   low   NaN        100    A
# 1   low   NaN        100    B
# 2   low   NaN        110    A
# 3  high   NaN        110    C
# 4   low   NaN        210    A
# 5  high   1.0        130    F

# %% [markdown]
# ### 手动设置采样权重

# %%
# weights每条数据采样到的概率
weights = [0,0,0,0.2,0.4,0.4]
df_inner.sample(n=2,weights=weights)
# Out:
#      id       date      city category_x  age   price  gender pay  m-point  \
# 3  1004 2013-01-05  shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06  shanghai      210-A   34     NaN    male   N       40
#
#   group  sign category_y size
# 3  high   NaN        110    C
# 4   low   NaN        210    A

# %% [markdown]
# ### 采样后不放回

# %%
# 不允许重复取样
df_inner.sample(n=6,replace=False)
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 5  1006 2013-01-07    beijing      130-F   32  4432.0  female   Y       40
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 1  1002 2013-01-03         sh      100-B   44     NaN  female   N       12
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
#
#   group  sign category_y size
# 5  high   1.0        130    F
# 3  high   NaN        110    C
# 0   low   NaN        100    A
# 2   low   NaN        110    A
# 1   low   NaN        100    B
# 4   low   NaN        210    A

# %% [markdown]
# ### 采样后放回

# %%
# 允许重复取样
df_inner.sample(n=6,replace=True)
# Out:
#      id       date       city category_x  age   price  gender pay  m-point  \
# 3  1004 2013-01-05   shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06   shanghai      210-A   34     NaN    male   N       40
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 2  1003 2013-01-04  guangzhou      110-A   54  2133.0    male   Y       20
# 0  1001 2013-01-02    beijing      100-A   23  1200.0    male   Y       10
#
#   group  sign category_y size
# 3  high   NaN        110    C
# 4   low   NaN        210    A
# 2   low   NaN        110    A
# 2   low   NaN        110    A
# 2   low   NaN        110    A
# 0   low   NaN        100    A

# %% [markdown]
# ### 数据表描述性统计

# %%
# round函数设置显示小数位，T表示转置
df_inner.describe().round(2).T
# Out:
#          count    mean      std     min      25%     50%      75%     max
# id         6.0  1003.5     1.87  1001.0  1002.25  1003.5  1004.75  1006.0
# age        6.0    36.5    10.88    23.0    32.00    33.0    41.50    54.0
# price      4.0  3299.5  1966.64  1200.0  1899.75  3282.5  4682.25  5433.0
# m-point    6.0    27.0    14.63    10.0    14.00    30.0    40.00    40.0
# sign       1.0     1.0      NaN     1.0     1.00     1.0     1.00     1.0

# %% [markdown]
# ### 计算列的标准差

# %% [markdown]
# ### 计算两个字段间的协方差

# %% [markdown]
# ### 数据表中所有字段间的协方差

# %% [markdown]
# ### 两个字段的相关性分析

# %% [markdown]
# ### 数据表的相关性分析

# %% [markdown]
# ## 数据输出

# %% [markdown]
# ### 写入Excel

# %% [markdown]
# ### 写入CSV
